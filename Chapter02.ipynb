# %% [markdown]
# # Deep Learning with PyTorch Step-by-Step: A Beginner's Guide

# %% [markdown]
# # Chapter 2

# %%
try:
    import google.colab
    import requests
    url = 'https://raw.githubusercontent.com/dvgodoy/PyTorchStepByStep/master/config.py'
    r = requests.get(url, allow_redirects=True)
    open('config.py', 'wb').write(r.content)    
except ModuleNotFoundError:
    pass

from config import *
config_chapter2()
# This is needed to render the plots in this chapter
from plots.chapter2 import *

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, TensorDataset, DataLoader
from torch.utils.data.dataset import random_split
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Rethinking the Training Loop

# %% [markdown]
# ### Model Training V0

# %%
# Runs data generation - so we do not need to copy code here
# %run -i data_generation/simple_linear_regression.py

# Runs the first two parts of the sequence: data preparation and model configuration
# %run -i data_preparation/v0.py
# %run -i model_configuration/v0.py

# %%
# %load model_training/v0.py

# Defines number of epochs
n_epochs = 1000

for epoch in range(n_epochs):
    # Sets model to TRAIN mode
    model.train()

    # Step 1 - Computes our model's predicted output - forward pass
    # No more manual prediction!
    yhat = model(x_train_tensor)
    
    # Step 2 - Computes the loss
    loss = loss_fn(yhat, y_train_tensor)

    # Step 3 - Computes gradients for both "a" and "b" parameters
    loss.backward()
    
    # Step 4 - Updates parameters using gradients and the learning rate
    optimizer.step()
    optimizer.zero_grad()

# %%
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9690]], device='cuda:0')), ('0.bias', tensor([1.0235], device='cuda:0'))])

# %% [markdown]
# ## Higher-Order Functions

# %%
def square(x):
    return x ** 2

def cube(x):
    return x ** 3

def fourth_power(x):
    return x ** 4

# and so on and so forth...

# %%
def generic_exponentiation(x, exponent):
    return x ** exponent

# %%
def skeleton_exponentiation(x):
    return x ** exponent

# %%
skeleton_exponentiation(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/projects/PyTorchStepByStep/model_configuration/v0.py in <module>
# ----> 1 skeleton_exponentiation(2)
#
# ~/projects/PyTorchStepByStep/model_configuration/v0.py in skeleton_exponentiation(x)
#       1 def skeleton_exponentiation(x):
# ----> 2     return x ** exponent
#
# NameError: name 'exponent' is not defined

# %%
def exponentiation_builder(exponent):
    def skeleton_exponentiation(x):
        return x ** exponent

    return skeleton_exponentiation

# %%
returned_function = exponentiation_builder(2)

returned_function
# Out:
# <function __main__.exponentiation_builder.<locals>.skeleton_exponentiation(x)>

# %%
returned_function(5)
# Out:
# 25

# %%
square = exponentiation_builder(2)
cube = exponentiation_builder(3)
fourth_power = exponentiation_builder(4)

# and so on and so forth...

# %% [markdown]
# ### Helper Function #1

# %%
def make_train_step(model, loss_fn, optimizer):
    # Builds function that performs a step in the train loop
    def perform_train_step(x, y):
        # Sets model to TRAIN mode
        model.train()
        
        # Step 1 - Computes our model's predicted output - forward pass
        yhat = model(x)
        # Step 2 - Computes the loss
        loss = loss_fn(yhat, y)
        # Step 3 - Computes gradients for both "a" and "b" parameters
        loss.backward()
        # Step 4 - Updates parameters using gradients and the learning rate
        optimizer.step()
        optimizer.zero_grad()
        
        # Returns the loss
        return loss.item()
    
    # Returns the function that will be called inside the train loop
    return perform_train_step

# %% [markdown]
# ### Model Configuration V1

# %%
# %run -i data_preparation/v0.py

# %%
# %%writefile model_configuration/v1.py

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Sets learning rate - this is "eta" ~ the "n" like Greek letter
lr = 0.1

torch.manual_seed(42)
# Now we can create a model and send it at once to the device
model = nn.Sequential(nn.Linear(1, 1)).to(device)

# Defines a SGD optimizer to update the parameters (now retrieved directly from the model)
optimizer = optim.SGD(model.parameters(), lr=lr)

# Defines a MSE loss function
loss_fn = nn.MSELoss(reduction='mean')

# Creates the train_step function for our model, loss function and optimizer
train_step = make_train_step(model, loss_fn, optimizer)
# Out:
# Overwriting model_configuration/v1.py

# %%
# %run -i model_configuration/v1.py

# %%
train_step
# Out:
# <function __main__.make_train_step.<locals>.perform_train_step(x, y)>

# %% [markdown]
# ### Model Training V1

# %%
# %%writefile model_training/v1.py

# Defines number of epochs
n_epochs = 1000

losses = []

# For each epoch...
for epoch in range(n_epochs):
    # Performs one train step and returns the corresponding loss
    loss = train_step(x_train_tensor, y_train_tensor)
    losses.append(loss)
# Out:
# Overwriting model_training/v1.py

# %%
# %run -i model_training/v1.py

# %%
# Checks model's parameters
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9690]], device='cuda:0')), ('0.bias', tensor([1.0235], device='cuda:0'))])

# %% [markdown]
# # Dataset

# %% [markdown]
# ### Cell 2.1

# %%
class CustomDataset(Dataset):
    def __init__(self, x_tensor, y_tensor):
        self.x = x_tensor
        self.y = y_tensor
        
    def __getitem__(self, index):
        return (self.x[index], self.y[index])

    def __len__(self):
        return len(self.x)

# Wait, is this a CPU tensor now? Why? Where is .to(device)?
x_train_tensor = torch.from_numpy(x_train).float()
y_train_tensor = torch.from_numpy(y_train).float()

train_data = CustomDataset(x_train_tensor, y_train_tensor)
print(train_data[0])
# Out:
# (tensor([0.7713]), tensor([2.4745]))

# %% [markdown]
# ## TensorDataset

# %% [markdown]
# ### Cell 2.2

# %%
train_data = TensorDataset(x_train_tensor, y_train_tensor)
print(train_data[0])
# Out:
# (tensor([0.7713]), tensor([2.4745]))

# %% [markdown]
# ## DataLoader

# %% [markdown]
# ### Cell 2.3

# %%
train_loader = DataLoader(dataset=train_data, batch_size=16, shuffle=True)

# %%
next(iter(train_loader))
# Out:
# [tensor([[0.1196],
#          [0.1395],
#          [0.2809],
#          [0.1834],
#          [0.3585],
#          [0.5427],
#          [0.0885],
#          [0.9489],
#          [0.9699],
#          [0.7751],
#          [0.9696],
#          [0.7320],
#          [0.0055],
#          [0.7069],
#          [0.8155],
#          [0.5979]]), tensor([[1.3214],
#          [1.3051],
#          [1.5846],
#          [1.4637],
#          [1.7462],
#          [2.2161],
#          [1.0708],
#          [2.8903],
#          [2.9727],
#          [2.4936],
#          [2.8401],
#          [2.4732],
#          [1.0632],
#          [2.4388],
#          [2.6606],
#          [2.0407]])]

# %% [markdown]
# ### Data Preparation V1

# %%
# %%writefile data_preparation/v1.py

# Our data was in Numpy arrays, but we need to transform them into PyTorch's Tensors
x_train_tensor = torch.from_numpy(x_train).float()
y_train_tensor = torch.from_numpy(y_train).float()

# Builds Dataset
train_data = TensorDataset(x_train_tensor, y_train_tensor)

# Builds DataLoader
train_loader = DataLoader(dataset=train_data, batch_size=16, shuffle=True)
# Out:
# Overwriting data_preparation/v1.py

# %%
# %run -i data_preparation/v1.py

# %% [markdown]
# ### Model Training V2

# %%
# %run -i model_configuration/v1.py

# %%
# %%writefile model_training/v2.py

# Defines number of epochs
n_epochs = 1000

losses = []

# For each epoch...
for epoch in range(n_epochs):
    # inner loop
    mini_batch_losses = []
    for x_batch, y_batch in train_loader:
        # the dataset "lives" in the CPU, so do our mini-batches
        # therefore, we need to send those mini-batches to the
        # device where the model "lives"
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)

        # Performs one train step and returns the corresponding loss 
        # for this mini-batch
        mini_batch_loss = train_step(x_batch, y_batch)
        mini_batch_losses.append(mini_batch_loss)

    # Computes average loss over all mini-batches - that's the epoch loss
    loss = np.mean(mini_batch_losses)
    
    losses.append(loss)
# Out:
# Overwriting model_training/v2.py

# %%
# %run -i model_training/v2.py

# %%
# Checks model's parameters
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9684]], device='cuda:0')), ('0.bias', tensor([1.0235], device='cuda:0'))])

# %% [markdown]
# ## Mini-Batch Inner Loop

# %% [markdown]
# ### Helper Function #2

# %%
def mini_batch(device, data_loader, step):
    mini_batch_losses = []
    for x_batch, y_batch in data_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)

        mini_batch_loss = step(x_batch, y_batch)
        mini_batch_losses.append(mini_batch_loss)

    loss = np.mean(mini_batch_losses)
    return loss

# %% [markdown]
# ### Model Training V3

# %%
# %run -i data_preparation/v1.py
# %run -i model_configuration/v1.py

# %%
# %%writefile model_training/v3.py

# Defines number of epochs
n_epochs = 200

losses = []

for epoch in range(n_epochs):
    # inner loop
    loss = mini_batch(device, train_loader, train_step)
    losses.append(loss)
# Out:
# Overwriting model_training/v3.py

# %%
# %run -i model_training/v3.py

# %%
# Checks model's parameters
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9687]], device='cuda:0')), ('0.bias', tensor([1.0236], device='cuda:0'))])

# %% [markdown]
# ## Random Split

# %% [markdown]
# ### Data Preparation V2

# %%
# %%writefile data_preparation/v2.py

torch.manual_seed(13)

# Builds tensors from numpy arrays BEFORE split
x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y).float()

# Builds dataset containing ALL data points
dataset = TensorDataset(x_tensor, y_tensor)

# Performs the split
ratio = .8
n_total = len(dataset)
n_train = int(n_total * ratio)
n_val = n_total - n_train

train_data, val_data = random_split(dataset, [n_train, n_val])

# Builds a loader of each set
train_loader = DataLoader(dataset=train_data, batch_size=16, shuffle=True)
val_loader = DataLoader(dataset=val_data, batch_size=16)
# Out:
# Overwriting data_preparation/v2.py

# %%
# %run -i data_preparation/v2.py

# %% [markdown]
# # Evaluation

# %% [markdown]
# ### Helper Function #3

# %%
def make_val_step(model, loss_fn):
    # Builds function that performs a step in the validation loop
    def perform_val_step(x, y):
        # Sets model to EVAL mode
        model.eval()
        
        # Step 1 - Computes our model's predicted output - forward pass
        yhat = model(x)
        # Step 2 - Computes the loss
        loss = loss_fn(yhat, y)
        # There is no need to compute Steps 3 and 4, since we don't update parameters during evaluation
        return loss.item()
    
    return perform_val_step

# %% [markdown]
# ### Model Configuration V2

# %%
# %%writefile model_configuration/v2.py

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Sets learning rate - this is "eta" ~ the "n" like Greek letter
lr = 0.1

torch.manual_seed(42)
# Now we can create a model and send it at once to the device
model = nn.Sequential(nn.Linear(1, 1)).to(device)

# Defines a SGD optimizer to update the parameters (now retrieved directly from the model)
optimizer = optim.SGD(model.parameters(), lr=lr)

# Defines a MSE loss function
loss_fn = nn.MSELoss(reduction='mean')

# Creates the train_step function for our model, loss function and optimizer
train_step = make_train_step(model, loss_fn, optimizer)

# Creates the val_step function for our model and loss function
val_step = make_val_step(model, loss_fn)
# Out:
# Overwriting model_configuration/v2.py

# %%
# %run -i model_configuration/v2.py

# %% [markdown]
# ### Model Training V4

# %%
# %%writefile model_training/v4.py

# Defines number of epochs
n_epochs = 200

losses = []
val_losses = []

for epoch in range(n_epochs):
    # inner loop
    loss = mini_batch(device, train_loader, train_step)
    losses.append(loss)
    
    # VALIDATION
    # no gradients in validation!
    with torch.no_grad():
        val_loss = mini_batch(device, val_loader, val_step)
        val_losses.append(val_loss)
# Out:
# Overwriting model_training/v4.py

# %%
# %run -i model_training/v4.py

# %%
# Checks model's parameters
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9419]], device='cuda:0')), ('0.bias', tensor([1.0244], device='cuda:0'))])

# %% [markdown]
# ## Plotting Losses

# %%
fig = plot_losses(losses, val_losses)

# %% [markdown]
# # TensorBoard

# %%
# tensorboard_cleanup()

# %%
if IS_BINDER:
    display(TB_LINK)
else:
    # %load_ext tensorboard
    # %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-236c4d01efb56c8c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-236c4d01efb56c8c");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## SummaryWriter

# %%
writer = SummaryWriter('runs/test')

# %% [markdown]
# ## add_graph

# %%
writer.add_graph(model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/projects/PyTorchStepByStep/model_training/v4.py in <module>
# ----> 1 writer.add_graph(model)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/utils/tensorboard/writer.py in add_graph(self, model, input_to_model, verbose)
#     680         if hasattr(model, 'forward'):
#     681             # A valid PyTorch model should have a 'forward' method
# --> 682             self._get_file_writer().add_graph(graph(model, input_to_model, verbose))
#     683         else:
#     684             # Caffe2 models do not have the 'forward' method
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/utils/tensorboard/_pytorch_graph.py in graph(model, args, verbose)
#     232     with torch.onnx.set_training(model, False):  # TODO: move outside of torch.onnx?
#     233         try:
# --> 234             trace = torch.jit.trace(model, args)
#     235             graph = trace.graph
#     236         except RuntimeError as e:
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/jit/__init__.py in trace(func, example_inputs, optimize, check_trace, check_inputs, check_tolerance, _force_outplace, _module_class, _compilation_unit)
#     856         return trace_module(func, {'forward': example_inputs}, None,
#     857                             check_trace, wrap_check_inputs(check_inputs),
# --> 858                             check_tolerance, _force_outplace, _module_class)
#     859
#     860     if (hasattr(func, '__self__') and isinstance(func.__self__, torch.nn.Module) and
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/jit/__init__.py in trace_module(mod, inputs, optimize, check_trace, check_inputs, check_tolerance, _force_outplace, _module_class, _compilation_unit)
#     994         # this is needed since Module.__call__ sets up some extra tracing
#     995         func = mod if method_name == "forward" else getattr(mod, method_name)
# --> 996         example_inputs = make_tuple(example_inputs)
#     997         module._c._create_method_from_trace(method_name, func, example_inputs, var_lookup_fn, _force_outplace)
#     998         check_trace_method = module._c._get_method(method_name)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/jit/__init__.py in make_tuple(example_inputs)
#     695     # done primarily so that weird iterables fail here and not pybind11 code
#     696     if not isinstance(example_inputs, tuple):
# --> 697         return tuple(example_inputs)
#     698     return example_inputs
#     699
#
# TypeError: 'NoneType' object is not iterable

# %%
# Fetching a tuple of feature (sample_x) and label (sample_y)
sample_x, sample_y = next(iter(train_loader))

# Since our model was sent to device, we need to do the same with the data
# Even here, both model and data need to be on the same device!
writer.add_graph(model, sample_x.to(device))

# %% [markdown]
# ## add_scalars

# %%
writer.add_scalars('loss', {'training': loss, 'validation': val_loss}, epoch)

# %% [markdown]
# ### Model Configuration V3

# %%
# %run -i data_preparation/v2.py

# %%
# %%writefile model_configuration/v3.py

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Sets learning rate - this is "eta" ~ the "n" like Greek letter
lr = 0.1

torch.manual_seed(42)
# Now we can create a model and send it at once to the device
model = nn.Sequential(nn.Linear(1, 1)).to(device)

# Defines a SGD optimizer to update the parameters (now retrieved directly from the model)
optimizer = optim.SGD(model.parameters(), lr=lr)

# Defines a MSE loss function
loss_fn = nn.MSELoss(reduction='mean')

# Creates the train_step function for our model, loss function and optimizer
train_step = make_train_step(model, loss_fn, optimizer)

# Creates the val_step function for our model and loss function
val_step = make_val_step(model, loss_fn)

# Creates a Summary Writer to interface with TensorBoard
writer = SummaryWriter('runs/simple_linear_regression')

# Fetches a single mini-batch so we can use add_graph
x_sample, y_sample = next(iter(train_loader))
writer.add_graph(model, x_sample.to(device))
# Out:
# Overwriting model_configuration/v3.py

# %%
# %run -i model_configuration/v3.py

# %% [markdown]
# ### Model Training V5

# %%
# %%writefile model_training/v5.py

# Defines number of epochs
n_epochs = 200

losses = []
val_losses = []

for epoch in range(n_epochs):
    # inner loop
    loss = mini_batch(device, train_loader, train_step)
    losses.append(loss)
    
    # VALIDATION
    # no gradients in validation!
    with torch.no_grad():
        val_loss = mini_batch(device, val_loader, val_step)
        val_losses.append(val_loss)
    
    # Records both losses for each epoch under the main tag "loss"
    writer.add_scalars(main_tag='loss',
                       tag_scalar_dict={'training': loss, 'validation': val_loss},
                       global_step=epoch)

# Closes the writer
writer.close()
# Out:
# Overwriting model_training/v5.py

# %%
# %run -i model_training/v5.py

# %%
# Checks model's parameters
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9448]], device='cuda:0')), ('0.bias', tensor([1.0295], device='cuda:0'))])

# %%
# This is just for convenience, so you don't have to scroll back up :-)
# %tensorboard --logdir runs
# Out:
# Reusing TensorBoard on port 6006 (pid 4351), started 0:00:10 ago. (Use '!kill 4351' to kill it.)
#       <iframe id="tensorboard-frame-96d144879bc13365" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-96d144879bc13365");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Saving and Loading Models

# %% [markdown]
# ## Saving

# %% [markdown]
# ### Cell 2.4

# %%
checkpoint = {'epoch': n_epochs,
              'model_state_dict': model.state_dict(),
              'optimizer_state_dict': optimizer.state_dict(),
              'loss': losses,
              'val_loss': val_losses}

torch.save(checkpoint, 'model_checkpoint.pth')

# %% [markdown]
# ## Resuming Training

# %% [markdown]
# ### Cell 2.5

# %%
# %run -i data_preparation/v2.py
# %run -i model_configuration/v3.py

# %%
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[0.7645]], device='cuda:0')), ('0.bias', tensor([0.8300], device='cuda:0'))])

# %% [markdown]
# ### Cell 2.6

# %%
checkpoint = torch.load('model_checkpoint.pth')

model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

saved_epoch = checkpoint['epoch']
saved_losses = checkpoint['loss']
saved_val_losses = checkpoint['val_loss']

model.train() # always use TRAIN for resuming training
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9448]], device='cuda:0')), ('0.bias', tensor([1.0295], device='cuda:0'))])

# %% [markdown]
# ### Cell 2.7

# %%
# %run -i model_training/v5.py

# %%
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9448]], device='cuda:0')), ('0.bias', tensor([1.0295], device='cuda:0'))])

# %%
fig = plot_resumed_losses(saved_epoch, saved_losses, saved_val_losses, range_before, n_epochs, losses, val_losses, range_after)

# %% [markdown]
# ## Deploying / Making Predictions

# %% [markdown]
# ### Cell 2.8

# %%
# %run -i model_configuration/v3.py

# %% [markdown]
# ### Cell 2.9

# %%
checkpoint = torch.load('model_checkpoint.pth')

model.load_state_dict(checkpoint['model_state_dict'])

print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9448]], device='cuda:0')), ('0.bias', tensor([1.0295], device='cuda:0'))])

# %% [markdown]
# ### Cell 2.10

# %%
new_inputs = torch.tensor([[.20], [.34], [.57]])

model.eval() # always use EVAL for fully trained models!
model(new_inputs.to(device))
# Out:
# tensor([[1.4185],
#         [1.6908],
#         [2.1381]], device='cuda:0', grad_fn=<AddmmBackward>)

# %% [markdown]
# # Putting It All Together

# %%
# %load data_preparation/v2.py

torch.manual_seed(13)

# Builds tensors from numpy arrays BEFORE split
x_tensor = torch.from_numpy(x).float()
y_tensor = torch.from_numpy(y).float()

# Builds dataset containing ALL data points
dataset = TensorDataset(x_tensor, y_tensor)

# Performs the split
ratio = .8
n_total = len(dataset)
n_train = int(n_total * ratio)
n_val = n_total - n_train

train_data, val_data = random_split(dataset, [n_train, n_val])

# Builds a loader of each set
train_loader = DataLoader(dataset=train_data, batch_size=16, shuffle=True)
val_loader = DataLoader(dataset=val_data, batch_size=16)

# %%
# %load model_configuration/v3.py

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Sets learning rate - this is "eta" ~ the "n" like Greek letter
lr = 0.1

torch.manual_seed(42)
# Now we can create a model and send it at once to the device
model = nn.Sequential(nn.Linear(1, 1)).to(device)

# Defines a SGD optimizer to update the parameters (now retrieved directly from the model)
optimizer = optim.SGD(model.parameters(), lr=lr)

# Defines a MSE loss function
loss_fn = nn.MSELoss(reduction='mean')

# Creates the train_step function for our model, loss function and optimizer
train_step = make_train_step(model, loss_fn, optimizer)

# Creates the val_step function for our model and loss function
val_step = make_val_step(model, loss_fn)

# Creates a Summary Writer to interface with TensorBoard
writer = SummaryWriter('runs/simple_linear_regression')

# Fetches a single mini-batch so we can use add_graph
x_sample, y_sample = next(iter(train_loader))
writer.add_graph(model, x_sample.to(device))

# %%
# %load model_training/v5.py

# Defines number of epochs
n_epochs = 200

losses = []
val_losses = []

for epoch in range(n_epochs):
    # inner loop
    loss = mini_batch(device, train_loader, train_step)
    losses.append(loss)
    
    # VALIDATION
    # no gradients in validation!
    with torch.no_grad():
        val_loss = mini_batch(device, val_loader, val_step)
        val_losses.append(val_loss)
    
    # Records both losses for each epoch under the main tag "loss"
    writer.add_scalars(main_tag='loss',
                       tag_scalar_dict={'training': loss, 'validation': val_loss},
                       global_step=epoch)

# Closes the writer
writer.close()

# %%
print(model.state_dict())
# Out:
# OrderedDict([('0.weight', tensor([[1.9440]], device='cuda:0')), ('0.bias', tensor([1.0249], device='cuda:0'))])

# %% [markdown]
# ### Weird plots in TensorBoard?
#
# Run this if you want to clean up a previous run and start fresh with TensorBoard :-)

# %%
import shutil

shutil.rmtree('./runs/simple_linear_regression/', ignore_errors=True)
